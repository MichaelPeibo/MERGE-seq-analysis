# %%
# %pwd
# Out:
# '/data0/xyz/xpb/tune_var/shap'

# %%
#Run the below code in your notebook to check the installed version
import shap
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import random
plt.rcParams['pdf.fonttype'] = 'truetype'
import numpy as np

# %%
df=pd.read_csv('var50_AI_valid_binary_normdata_allcells.csv')

# %%
df.head()
# Out:
#       Tshz2  Cplx3       Npy      Myl4  Pbld1   Gm13889  Ptgs2  Dlk1  \
# 0  0.000000    0.0  0.000000  0.000000    0.0  1.147602    0.0   0.0
# 1  0.000000    0.0  0.000000  1.736971    0.0  0.000000    0.0   0.0
# 2  0.000000    0.0  0.000000  0.000000    0.0  0.000000    0.0   0.0
# 3  0.000000    0.0  3.035425  0.000000    0.0  0.000000    0.0   0.0
# 4  4.304573    0.0  1.577758  4.004004    0.0  0.000000    0.0   0.0
#
#       Lypd1     Nr4a2      Etv1       Cck     Cyr61  Pou3f1      Egr4  \
# 0  0.000000  1.147602  1.147602  4.931883  0.000000     0.0  3.963004
# 1  0.000000  0.000000  0.000000  0.000000  1.205988     0.0  0.000000
# 2  2.038546  1.171391  1.171391  0.000000  1.696158     0.0  3.146940
# 3  0.000000  0.000000  0.000000  5.236935  0.000000     0.0  0.000000
# 4  4.355191  0.000000  4.304573  0.000000  0.000000     0.0  0.000000
#
#        Nnat  Aldh1a3  Stxbp6     Arl4d     Synpr      Bdnf  Marcksl1  \
# 0  0.000000      0.0     0.0  0.000000  2.901699  2.464121  1.667945
# 1  0.000000      0.0     0.0  0.000000  0.000000  0.000000  0.000000
# 2  3.399336      0.0     0.0  0.000000  0.000000  0.000000  0.000000
# 3  4.299134      0.0     0.0  0.000000  0.000000  0.000000  0.000000
# 4  0.000000      0.0     0.0  1.577758  0.000000  2.161962  3.328934
#
#     Gadd45g  S100a6   Gadd45b  Gm45833  Gm10635     C1ql3    Hspa1a     Rab3c  \
# 0  1.667945     0.0  2.464121      0.0      0.0  3.921270  0.000000  2.632161
# 1  1.205988     0.0  0.000000      0.0      0.0  0.000000  1.205988  1.205988
# 2  1.171391     0.0  1.696158      0.0      0.0  0.000000  2.664367  1.171391
# 3  1.163492     0.0  0.000000      0.0      0.0  3.035425  0.000000  2.653703
# 4  0.000000     0.0  0.000000      0.0      0.0  1.577758  0.000000  2.528305
#
#       Htr2c  Adamts1      Rprm     Nptxr  Pdyn      Btg2      Rorb     Rxfp1  \
# 0  0.000000      0.0  1.147602  3.113795   0.0  2.464121  2.008468  2.464121
# 1  0.000000      0.0  3.960456  0.000000   0.0  0.000000  0.000000  0.000000
# 2  1.171391      0.0  3.600694  1.696158   0.0  3.537974  0.000000  0.000000
# 3  0.000000      0.0  0.000000  3.704252   0.0  0.000000  0.000000  3.227320
# 4  3.328934      0.0  1.577758  2.795837   0.0  3.006693  0.000000  0.000000
#
#    Defb1      Rgs5       Bc1  Vip     Calb1   Fam19a1      Cnr1      Ctgf  \
# 0    0.0  1.147602  2.901699  0.0  0.000000  2.632161  3.437491  0.000000
# 1    0.0  0.000000  1.736971  0.0  0.000000  0.000000  1.205988  0.000000
# 2    0.0  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  1.696158
# 3    0.0  0.000000  2.653703  0.0  1.163492  0.000000  1.686803  0.000000
# 4    0.0  0.000000  1.577758  0.0  0.000000  0.000000  1.577758  0.000000
#
#       Npas4  Ighm  Gpr88       Ptn  binary
# 0  2.901699   0.0    0.0  0.000000       1
# 1  0.000000   0.0    0.0  0.000000       0
# 2  1.696158   0.0    0.0  0.000000       0
# 3  1.163492   0.0    0.0  1.163492       0
# 4  0.000000   0.0    0.0  1.577758       0

# %%
df['binary'].value_counts()
# Out:
# 0    8710
# 1     658
# Name: binary, dtype: int64

# %%
exp1 = setup(df, target = 'binary',session_id=1,silent=True)
# Out:
# <style type="text/css">
# #T_0ba65_row0_col1, #T_0ba65_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0ba65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ba65_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0ba65_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ba65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ba65_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0ba65_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ba65_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0ba65_row1_col1" class="data row1 col1" >binary</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0ba65_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_0ba65_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0ba65_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_0ba65_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0ba65_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_0ba65_row4_col1" class="data row4 col1" >(9368, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0ba65_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_0ba65_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0ba65_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_0ba65_row6_col1" class="data row6 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0ba65_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_0ba65_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0ba65_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_0ba65_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0ba65_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_0ba65_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0ba65_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_0ba65_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0ba65_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_0ba65_row11_col1" class="data row11 col1" >(6557, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0ba65_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_0ba65_row12_col1" class="data row12 col1" >(2811, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0ba65_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_0ba65_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0ba65_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_0ba65_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0ba65_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_0ba65_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0ba65_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_0ba65_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0ba65_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_0ba65_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0ba65_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_0ba65_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0ba65_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_0ba65_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0ba65_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_0ba65_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0ba65_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_0ba65_row21_col1" class="data row21 col1" >869b</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0ba65_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_0ba65_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0ba65_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_0ba65_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_0ba65_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_0ba65_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_0ba65_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_0ba65_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_0ba65_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_0ba65_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_0ba65_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_0ba65_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_0ba65_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_0ba65_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_0ba65_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_0ba65_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0ba65_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_0ba65_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_0ba65_

# %%
nb = create_model('nb')
# Out:
# <style type="text/css">
# #T_5b050_row10_col0, #T_5b050_row10_col1, #T_5b050_row10_col2, #T_5b050_row10_col3, #T_5b050_row10_col4, #T_5b050_row10_col5, #T_5b050_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b050">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b050_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b050_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b050_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b050_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b050_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b050_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b050_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b050_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b050_row0_col0" class="data row0 col0" >0.6905</td>
#       <td id="T_5b050_row0_col1" class="data row0 col1" >0.8452</td>
#       <td id="T_5b050_row0_col2" class="data row0 col2" >0.8182</td>
#       <td id="T_5b050_row0_col3" class="data row0 col3" >0.1558</td>
#       <td id="T_5b050_row0_col4" class="data row0 col4" >0.2618</td>
#       <td id="T_5b050_row0_col5" class="data row0 col5" >0.1681</td>
#       <td id="T_5b050_row0_col6" class="data row0 col6" >0.2616</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b050_row1_col0" class="data row1 col0" >0.6723</td>
#       <td id="T_5b050_row1_col1" class="data row1 col1" >0.8524</td>
#       <td id="T_5b050_row1_col2" class="data row1 col2" >0.9091</td>
#       <td id="T_5b050_row1_col3" class="data row1 col3" >0.1594</td>
#       <td id="T_5b050_row1_col4" class="data row1 col4" >0.2712</td>
#       <td id="T_5b050_row1_col5" class="data row1 col5" >0.1773</td>
#       <td id="T_5b050_row1_col6" class="data row1 col6" >0.2904</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b050_row2_col0" class="data row2 col0" >0.6890</td>
#       <td id="T_5b050_row2_col1" class="data row2 col1" >0.8930</td>
#       <td id="T_5b050_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_5b050_row2_col3" class="data row2 col3" >0.1774</td>
#       <td id="T_5b050_row2_col4" class="data row2 col4" >0.3014</td>
#       <td id="T_5b050_row2_col5" class="data row2 col5" >0.2115</td>
#       <td id="T_5b050_row2_col6" class="data row2 col6" >0.3439</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b050_row3_col0" class="data row3 col0" >0.6905</td>
#       <td id="T_5b050_row3_col1" class="data row3 col1" >0.8509</td>
#       <td id="T_5b050_row3_col2" class="data row3 col2" >0.9318</td>
#       <td id="T_5b050_row3_col3" class="data row3 col3" >0.1701</td>
#       <td id="T_5b050_row3_col4" class="data row3 col4" >0.2877</td>
#       <td id="T_5b050_row3_col5" class="data row3 col5" >0.1966</td>
#       <td id="T_5b050_row3_col6" class="data row3 col6" >0.3139</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b050_row4_col0" class="data row4 col0" >0.7012</td>
#       <td id="T_5b050_row4_col1" class="data row4 col1" >0.8482</td>
#       <td id="T_5b050_row4_col2" class="data row4 col2" >0.9318</td>
#       <td id="T_5b050_row4_col3" class="data row4 col3" >0.1752</td>
#       <td id="T_5b050_row4_col4" class="data row4 col4" >0.2950</td>
#       <td id="T_5b050_row4_col5" class="data row4 col5" >0.2052</td>
#       <td id="T_5b050_row4_col6" class="data row4 col6" >0.3219</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b050_row5_col0" class="data row5 col0" >0.6951</td>
#       <td id="T_5b050_row5_col1" class="data row5 col1" >0.8506</td>
#       <td id="T_5b050_row5_col2" class="data row5 col2" >0.9333</td>
#       <td id="T_5b050_row5_col3" class="data row5 col3" >0.1757</td>
#       <td id="T_5b050_row5_col4" class="data row5 col4" >0.2958</td>
#       <td id="T_5b050_row5_col5" class="data row5 col5" >0.2039</td>
#       <td id="T_5b050_row5_col6" class="data row5 col6" >0.3209</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b050_row6_col0" class="data row6 col0" >0.7058</td>
#       <td id="T_5b050_row6_col1" class="data row6 col1" >0.8530</td>
#       <td id="T_5b050_row6_col2" class="data row6 col2" >0.9556</td>
#       <td id="T_5b050_row6_col3" class="data row6 col3" >0.1838</td>
#       <td id="T_5b050_row6_col4" class="data row6 col4" >0.3082</td>
#       <td id="T_5b050_row6_col5" class="data row6 col5" >0.2183</td>
#       <td id="T_5b050_row6_col6" class="data row6 col6" >0.3393</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b050_row7_col0" class="data row7 col0" >0.6885</td>
#       <td id="T_5b050_row7_col1" class="data row7 col1" >0.8328</td>
#       <td id="T_5b050_row7_col2" class="data row7 col2" >0.9091</td>
#       <td id="T_5b050_row7_col3" class="data row7 col3" >0.1667</td>
#       <td id="T_5b050_row7_col4" class="data row7 col4" >0.2817</td>
#       <td id="T_5b050_row7_col5" class="data row7 col5" >0.1897</td>
#       <td id="T_5b050_row7_col6" class="data row7 col6" >0.3022</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b050_row8_col0" class="data row8 col0" >0.7084</td>
#       <td id="T_5b050_row8_col1" class="data row8 col1" >0.8462</td>
#       <td id="T_5b050_row8_col2" class="data row8 col2" >0.9318</td>
#       <td id="T_5b050_row8_col3" class="data row8 col3" >0.1790</td>
#       <td id="T_5b050_row8_col4" class="data row8 col4" >0.3004</td>
#       <td id="T_5b050_row8_col5" class="data row8 col5" >0.2115</td>
#       <td id="T_5b050_row8_col6" class="data row8 col6" >0.3276</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b050_row9_col0" class="data row9 col0" >0.6580</td>
#       <td id="T_5b050_row9_col1" class="data row9 col1" >0.8217</td>
#       <td id="T_5b050_row9_col2" class="data row9 col2" >0.9091</td>
#       <td id="T_5b050_row9_col3" class="data row9 col3" >0.1538</td>
#       <td id="T_5b050_row9_col4" class="data row9 col4" >0.2632</td>
#       <td id="T_5b050_row9_col5" class="data row9 col5" >0.1675</td>
#       <td id="T_5b050_row9_col6" class="data row9 col6" >0.2809</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5b050_row10_col0" class="data row10 col0" >0.6899</td>
#       <td id="T_5b050_row10_col1" class="data row10 col1" >0.8494</td>
#       <td id="T_5b050_row10_col2" class="data row10 col2" >0.9230</td>
#       <td id="T_5b050_row10_col3" class="data row10 col3" >0.1697</td>
#       <td id="T_5b050_row10_col4" class="data row10 col4" >0.2866</td>
#       <td id="T_5b050_row10_col5" class="data row10 col5" >0.1950</td>
#       <td id="T_5b050_row10_col6" class="data row10 col6" >0.3103</td>
#     </tr>
#     <tr>
#       <th id="T_5b050_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5b050_row11_col0" class="data row11 col0" >0.0144</td>
#       <td id="T_5b050_row11_col1" class="data row11 col1" >0.0173</td>
#       <td id="T_5b050_row11_col2" class="data row11 col2" >0.0435</td>
#       <td id="T_5b050_row11_col3" class="data row11 col3" >0.0099</td>
#       <td id="T_5b050_row11_col4

# %%
Xtest = get_config('X_test')
ytest = get_config('y_test')
X_train = get_config('X_train')
y_train = get_config('y_train')

# %%
sample_size=1000
sub_sampled_train_data = shap.sample(X_train, sample_size, random_state=0)
sub_sampled_test_data = shap.sample(Xtest, sample_size, random_state=0)

# %%
# explain all the predictions in the test set
explainer = shap.KernelExplainer(nb.predict, sub_sampled_train_data)## nb,predict_proba generates barplot

# %%
shap_values = explainer.shap_values(sub_sampled_test_data)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 shap_values = explainer.shap_values(sub_sampled_test_data)
#
# File ~/miniconda3/envs/xpb1/lib/python3.9/site-packages/shap/explainers/_kernel.py:190, in Kernel.shap_values(self, X, **kwargs)
#     188 if self.keep_index:
#     189     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 190 explanations.append(self.explain(data, **kwargs))
#     191 if kwargs.get("gc_collect", False):
#     192     gc.collect()
#
# File ~/miniconda3/envs/xpb1/lib/python3.9/site-packages/shap/explainers/_kernel.py:382, in Kernel.explain(self, incoming_instance, **kwargs)
#     379     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     381 # execute the model on the synthetic samples we have created
# --> 382 self.run()
#     384 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     385 phi = np.zeros((self.data.groups_size, self.D))
#
# File ~/miniconda3/envs/xpb1/lib/python3.9/site-packages/shap/explainers/_kernel.py:530, in Kernel.run(self)
#     528 eyVal = np.zeros(self.D)
#     529 for j in range(0, self.N):
# --> 530     eyVal += self.y[i * self.N + j, :] * self.data.weights[j]
#     532 self.ey[i, :] = eyVal
#     533 self.nsamplesRun += 1
#
# KeyboardInterrupt:

# %%
np.save("ai_shap_values_allcells.npy", shap_values)
#pd.DataFrame(shap_values).to_csv("lh_shap_values_500cells.csv")

# %%
shap.summary_plot(shap_values, sub_sampled_test_data,show=False)
plt.savefig("AI var shap plot nb .pdf",dpi=1000)

# %%
save_model(nb, model_name='model_AI_20220921')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='binary',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='binary')),
#                  ('fix_perfect', Remove_100(target='binary')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   GaussianNB(priors=None, var_smoothing=1e-09)]],
#           verbose=False),
#  'model_AI_20220921.pkl')
