# %%
# %pwd
# Out:
# '/home/xupb/scRNA_data/mouse_pfc/manuscripts/scanpy'

# %%
#Run the below code in your notebook to check the installed version
import pandas as pd
from pycaret.utils import version
version()
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import column_or_1d
from pycaret.classification import *
# Out:
# 1.0.0

# %%
data=pd.read_csv('/home/xupb/scRNA_data/mouse_pfc/manuscripts/barcode_projection/random_150_MD_valid_binary_normdata.csv',index_col=0)

# %%
data['binary'].value_counts()
# Out:
# Others      2539
# MD_valid    1017
# Name: binary, dtype: int64

# %%
data.head()
# Out:
#                         Nckap1l     Sar1b     Cebpg     Eif2d      Nmt1  \
# pfc_1_AAACCCAAGTCGTTAC      0.0  1.147602  2.008468  1.147602  1.667945
# pfc_1_AAAGGGCGTGGCATCC      0.0  0.000000  1.411504  0.000000  1.974670
# pfc_1_AACCCAATCCGCTTAC      0.0  0.000000  1.034382  1.531852  1.034382
# pfc_1_AAGAACAAGAGAGCCT      0.0  1.996056  1.137830  1.137830  1.137830
# pfc_1_ACAAGCTCAAAGCACG      0.0  0.818405  0.000000  0.000000  1.262363
#
#                             Tcta  Gm26619  Gm4779  Tmem129   Rnf144a  ...  \
# pfc_1_AAACCCAAGTCGTTAC  0.000000      0.0     0.0      0.0  0.000000  ...
# pfc_1_AAAGGGCGTGGCATCC  0.000000      0.0     0.0      0.0  0.000000  ...
# pfc_1_AACCCAATCCGCTTAC  0.000000      0.0     0.0      0.0  1.531852  ...
# pfc_1_AAGAACAAGAGAGCCT  1.137830      0.0     0.0      0.0  0.000000  ...
# pfc_1_ACAAGCTCAAAGCACG  1.262363      0.0     0.0      0.0  1.568750  ...
#
#                         Gm48420    Dnaja2  Gm15063      Tesc     Pcyt2  \
# pfc_1_AAACCCAAGTCGTTAC      0.0  2.632161      0.0  2.008468  2.008468
# pfc_1_AAAGGGCGTGGCATCC      0.0  2.332762      0.0  2.332762  0.000000
# pfc_1_AACCCAATCCGCTTAC      0.0  1.531852      0.0  1.034382  1.034382
# pfc_1_AAGAACAAGAGAGCCT      0.0  2.618851      0.0  2.888143  0.000000
# pfc_1_ACAAGCTCAAAGCACG      0.0  2.151912      0.0  1.568750  0.818405
#
#                            Abcf2   Aldh3a2   Gm17056     Arrb1  binary
# pfc_1_AAACCCAAGTCGTTAC  1.147602  0.000000  1.147602  0.000000  Others
# pfc_1_AAAGGGCGTGGCATCC  1.974670  0.000000  0.000000  1.974670  Others
# pfc_1_AACCCAATCCGCTTAC  1.531852  1.531852  0.000000  2.110634  Others
# pfc_1_AAGAACAAGAGAGCCT  1.656318  1.137830  0.000000  1.137830  Others
# pfc_1_ACAAGCTCAAAGCACG  1.568750  0.000000  1.262363  1.568750  Others
#
# [5 rows x 151 columns]

# %%
data['binary']=pd.factorize(data['binary'])[0]

# %%
data.head()
# Out:
#                         Nckap1l     Sar1b     Cebpg     Eif2d      Nmt1  \
# pfc_1_AAACCCAAGTCGTTAC      0.0  1.147602  2.008468  1.147602  1.667945
# pfc_1_AAAGGGCGTGGCATCC      0.0  0.000000  1.411504  0.000000  1.974670
# pfc_1_AACCCAATCCGCTTAC      0.0  0.000000  1.034382  1.531852  1.034382
# pfc_1_AAGAACAAGAGAGCCT      0.0  1.996056  1.137830  1.137830  1.137830
# pfc_1_ACAAGCTCAAAGCACG      0.0  0.818405  0.000000  0.000000  1.262363
#
#                             Tcta  Gm26619  Gm4779  Tmem129   Rnf144a  ...  \
# pfc_1_AAACCCAAGTCGTTAC  0.000000      0.0     0.0      0.0  0.000000  ...
# pfc_1_AAAGGGCGTGGCATCC  0.000000      0.0     0.0      0.0  0.000000  ...
# pfc_1_AACCCAATCCGCTTAC  0.000000      0.0     0.0      0.0  1.531852  ...
# pfc_1_AAGAACAAGAGAGCCT  1.137830      0.0     0.0      0.0  0.000000  ...
# pfc_1_ACAAGCTCAAAGCACG  1.262363      0.0     0.0      0.0  1.568750  ...
#
#                         Gm48420    Dnaja2  Gm15063      Tesc     Pcyt2  \
# pfc_1_AAACCCAAGTCGTTAC      0.0  2.632161      0.0  2.008468  2.008468
# pfc_1_AAAGGGCGTGGCATCC      0.0  2.332762      0.0  2.332762  0.000000
# pfc_1_AACCCAATCCGCTTAC      0.0  1.531852      0.0  1.034382  1.034382
# pfc_1_AAGAACAAGAGAGCCT      0.0  2.618851      0.0  2.888143  0.000000
# pfc_1_ACAAGCTCAAAGCACG      0.0  2.151912      0.0  1.568750  0.818405
#
#                            Abcf2   Aldh3a2   Gm17056     Arrb1  binary
# pfc_1_AAACCCAAGTCGTTAC  1.147602  0.000000  1.147602  0.000000       0
# pfc_1_AAAGGGCGTGGCATCC  1.974670  0.000000  0.000000  1.974670       0
# pfc_1_AACCCAATCCGCTTAC  1.531852  1.531852  0.000000  2.110634       0
# pfc_1_AAGAACAAGAGAGCCT  1.656318  1.137830  0.000000  1.137830       0
# pfc_1_ACAAGCTCAAAGCACG  1.568750  0.000000  1.262363  1.568750       0
#
# [5 rows x 151 columns]

# %%
exp1 = setup(data, target = 'binary',session_id=1)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_fa741e30_c9aa_11ea_8d5d_d094666d9817row0_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row3_col1" class="data row3 col1" >(3556, 151)</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row5_col1" class="data row5 col1" >150</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row10_col1" class="data row10 col1" >(3556, 151)</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row11_col1" class="data row11 col1" >(2489, 150)</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row12_col1" class="data row12 col1" >(1067, 150)</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_fa741e30_c9aa_11ea_8d5d_d094666d9817row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="

# %%
tuned_xgboost = tune_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8554  0.8666  0.6761  0.7869  0.7273  0.6297
# 1       0.8193  0.8718  0.7042  0.6757  0.6897  0.5623
# 2       0.7510  0.8095  0.6056  0.5584  0.5811  0.4044
# 3       0.8273  0.9064  0.6761  0.7059  0.6906  0.5709
# 4       0.8273  0.8547  0.6901  0.7000  0.6950  0.5746
# 5       0.7952  0.8693  0.6761  0.6316  0.6531  0.5080
# 6       0.8153  0.8712  0.6901  0.6712  0.6806  0.5506
# 7       0.8032  0.8470  0.6528  0.6620  0.6573  0.5193
# 8       0.8072  0.8582  0.6944  0.6579  0.6757  0.5387
# 9       0.7540  0.7482  0.5493  0.5735  0.5612  0.3904
# Mean    0.8055  0.8503  0.6615  0.6623  0.6611  0.5249
# SD      0.0308  0.0410  0.0458  0.0622  0.0493  0.0712

# %%
save_experiment('Experiment_MD_random_19July2020')
# Out:
# Experiment Succesfully Saved

# %%
saved_experiment = load_experiment('Experiment_MD_random_19July2020')
# Out:
#                            Object
# 0     Classification Setup Config
# 1                  X_training Set
# 2                  y_training Set
# 3                      X_test Set
# 4                      y_test Set
# 5         Transformation Pipeline
# 6             Tuned XGBClassifier
# 7  Tuned XGBClassifier Score Grid

# %%
exp1=saved_experiment
tuned_xgboost=exp1[6]

# %%
from sklearn.model_selection import train_test_split
from pycaret import preprocess
from sklearn import metrics

X = exp1[3]
y = exp1[4]

# Number of random trials
NUM_TRIALS = 10
d = []
for i in range(NUM_TRIALS):
    
    X_train, X_test, y_train, y_test  = train_test_split(X, y,stratify=y, test_size=0.9,  random_state=i)
    pred_ =tuned_xgboost.predict(X_test)
    pred_prob = tuned_xgboost.predict_proba(X_test)[:,1]
    acc = metrics.accuracy_score(y_test,pred_)
    auc = metrics.roc_auc_score(y_test,pred_prob)
    prec = metrics.precision_score(y_test,pred_)
    f1 = metrics.f1_score(y_test,pred_)
    recall = metrics.recall_score(y_test,pred_)
    kappa = metrics.cohen_kappa_score(y_test,pred_)
    d.append(
        {
           'Accuracy' : acc, 'AUC': auc, 'F1' : f1, 'Precision':prec, 'Recall':recall, 'Kappa':kappa
        }
    )
    model_results=pd.DataFrame(d)

# %%
model_results
# Out:
#         AUC  Accuracy        F1     Kappa  Precision    Recall
# 0  0.832468  0.795005  0.629002  0.487628   0.652344  0.607273
# 1  0.828322  0.789802  0.624535  0.478682   0.638783  0.610909
# 2  0.841103  0.800208  0.641791  0.503394   0.659004  0.625455
# 3  0.831884  0.789802  0.621723  0.476371   0.640927  0.603636
# 4  0.832828  0.791883  0.626866  0.482702   0.643678  0.610909
# 5  0.825709  0.788762  0.621974  0.475523   0.637405  0.607273
# 6  0.823981  0.785640  0.615672  0.467183   0.632184  0.600000
# 7  0.826059  0.788762  0.621974  0.475523   0.637405  0.607273
# 8  0.835288  0.790843  0.622889  0.478385   0.643411  0.603636
# 9  0.832128  0.792924  0.626642  0.483575   0.647287  0.607273
