# %%
# %pwd
# Out:
# '/data0/xyz/xpb/tune_var'

# %%
#Run the below code in your notebook to check the installed version
#import shap
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.utils import shuffle
import random
import pandas as pd
plt.rcParams['pdf.fonttype'] = 'truetype'

# %%
sample_trials=list(range(1,101))
num_vars=[2,5,10,20,50,100,200,300,400,500,1000,2000,5000]

# %%
for x in sample_trials:
    for n in num_vars:
        df = pd.read_csv('./sampling_results/var5000_DMS_valid_binary_normdata_1000cells_%d.csv' % x)
        AUC = []
        Accuracy = []
        Recall = []
        Prec = []
        F1 = []
        Kappa = []
        MCC = []
        
        input_data = df.iloc[:, 0:n]
        input_data['binary'] = df['binary']
        
        exp1 = setup(input_data, target='binary', session_id=1, index=False)
        gbc = create_model('gbc')
        Xtest = get_config('X_test')
        ytest = get_config('y_test')
        predict_model(gbc)
        
        AUC.append(pull()['AUC'][0])
        Accuracy.append(pull()['Accuracy'][0])
        Recall.append(pull()['Recall'][0])
        Prec.append(pull()['Prec.'][0])
        F1.append(pull()['F1'][0])
        Kappa.append(pull()['Kappa'][0])
        MCC.append(pull()['MCC'][0])
        
        AUC_df = pd.DataFrame(AUC)
        Accuracy_df = pd.DataFrame(Accuracy)
        Recall_df = pd.DataFrame(Recall)
        Prec_df = pd.DataFrame(Prec)
        F1_df = pd.DataFrame(F1)
        Kappa_df = pd.DataFrame(Kappa)
        MCC_df = pd.DataFrame(MCC)
        
        AUC_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_AUC_%d.csv" % (n, x))
        Accuracy_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_Acc_%d.csv" % (n, x))
        Recall_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_Recall_%d.csv" % (n, x))
        Prec_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_Prec_%d.csv" % (n, x))
        F1_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_F1_%d.csv" % (n, x))
        Kappa_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_Kappa_%d.csv" % (n, x))
        MCC_df.to_csv("./dms_results/DMS_var_model_results_%d_genes_MCC_%d.csv" % (n, x))
# Out:
# <style type="text/css">
# #T_95769_row10_col0, #T_95769_row10_col1, #T_95769_row10_col2, #T_95769_row10_col3, #T_95769_row10_col4, #T_95769_row10_col5, #T_95769_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_95769">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95769_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_95769_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_95769_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_95769_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_95769_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_95769_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_95769_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
