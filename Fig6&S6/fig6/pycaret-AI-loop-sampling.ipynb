# %%
# %pwd
# Out:
# '/Users/peiboxu/Desktop/merge-seq analysis/elife_revision/code_file'

# %%
#Run the below code in your notebook to check the installed version
#import shap
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.utils import shuffle
import random
import pandas as pd
plt.rcParams['pdf.fonttype'] = 'truetype'

# %%
sample_trials=list(range(1,101))
num_vars=[2,5,10,20,50,100,200,300,400,500,1000,2000,5000]#

# %%
df=pd.read_csv('../results/var5000_LH_valid_binary_normdata_1000cells_100.csv')

# %%
input_data.head()
# Out:
#       Tshz2  Npy      Myl4     Lypd1       Cck   Gm13889      Etv1     Ptgs2  \
# 0  0.000000  0.0  1.752056  1.218829  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.0  1.280100  0.000000  5.103584  0.000000  1.280100  2.173728
# 2  0.000000  0.0  1.247290  2.390925  2.390925  0.000000  0.000000  1.785371
# 3  4.376232  0.0  3.386395  4.330310  0.000000  0.000000  3.109926  0.000000
# 4  2.673722  0.0  2.844478  2.844478  0.000000  1.307999  3.055921  0.000000
#
#    Cplx3      Egr4  ...     Npas4  Gpr88      Btg2       Ptn       Grp  \
# 0    0.0  0.000000  ...  0.000000    0.0  1.752056  1.218829  0.000000
# 1    0.0  0.000000  ...  1.280100    0.0  0.000000  0.000000  1.280100
# 2    0.0  4.767307  ...  3.765267    0.0  2.765399  0.000000  3.821138
# 3    0.0  0.000000  ...  1.519491    0.0  3.109926  0.000000  3.386395
# 4    0.0  1.619021  ...  1.855912    0.0  3.282348  1.307999  0.854152
#
#      Deptor     Hspa8      Scg2      Ighm  binary
# ...

# %%
n=100
AUC = []
Accuracy = []
Recall = []
Prec = []
F1 = []
Kappa = []
MCC = []
input_data=df.iloc[:,0:n]
input_data['binary']=df['binary']

# %%
exp1 = setup(input_data, target = 'binary',session_id=1, index=False)
# Out:
# <style type="text/css">
# #T_fc90f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fc90f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc90f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fc90f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc90f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc90f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fc90f_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc90f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc90f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fc90f_row1_col1" class="data row1 col1" >binary</td>
#     </tr>
#     <tr>
#       <th id="T_fc90f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                15:49:48
# Status     . . . . . . . . . . . . . . . . . .        Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Classifier
# <style type="text/css">
# #T_a554e th {
#   text-align: left;
# }
# #T_a554e_row0_col0, #T_a554e_row0_col1, #T_a554e_row0_col2, #T_a554e_row0_col3, #T_a554e_row0_col4, #T_a554e_row0_col5, #T_a554e_row0_col6, #T_a554e_row0_col7, #T_a554e_row0_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_a554e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a554e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a554e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a554e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a554e_level0_col3" class="col_heading level0 col3" >Recall</th>
# ...

# %%
gbc = create_model('gbc')
# Out:
# <style type="text/css">
# #T_73d7a_row10_col0, #T_73d7a_row10_col1, #T_73d7a_row10_col2, #T_73d7a_row10_col3, #T_73d7a_row10_col4, #T_73d7a_row10_col5, #T_73d7a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_73d7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73d7a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_73d7a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_73d7a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_73d7a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_73d7a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_73d7a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_73d7a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
            
            gbc = create_model('gbc')
            Xtest = get_config('X_test')
            ytest = get_config('y_test')
            predict_model(gbc);
            AUC.append(pull()['AUC'][0])
            Accuracy.append(pull()['Accuracy'][0])
            Recall.append(pull()['Recall'][0])
            Prec.append(pull()['Prec.'][0])
            F1.append(pull()['F1'][0])
            Kappa.append(pull()['Kappa'][0])
            MCC.append(pull()['MCC'][0])
            AUC_df=pd.DataFrame(AUC)
            Accuracy_df=pd.DataFrame(Accuracy)
            Recall_df=pd.DataFrame(Recall)
            Prec_df=pd.DataFrame(Prec)
            F1_df=pd.DataFrame(F1)
            Kappa_df=pd.DataFrame(Kappa)
            MCC_df=pd.DataFrame(MCC)
            AUC_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_AUC_%d.csv" % (n,x))
            Accuracy_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Acc_%d.csv" % (n,x))
            Recall_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Recall_%d.csv" % (n,x))
            Prec_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Prec_%d.csv" % (n,x))
            F1_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_F1_%d.csv" % (n,x))
            Kappa_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Kappa_%d.csv" % (n,x))
            MCC_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_MCC_%d.csv" % (n,x))

# %%
    for x in sample_trials:
        df=pd.read_csv('../results/var10000_AI_valid_binary_normdata_1000cells_%d.csv' % (x),index_col=0)
        for n in num_vars:
            AUC = []
            Accuracy = []
            Recall = []
            Prec = []
            F1 = []
            Kappa = []
            MCC = []
            input_data=df.iloc[:,0:n]
            input_data['binary']=df['binary']
            exp1 = setup(input_data, target = 'binary',session_id=1,index=False)
            gbc = create_model('gbc')
            Xtest = get_config('X_test')
            ytest = get_config('y_test')
            predict_model(gbc);
            AUC.append(pull()['AUC'][0])
            Accuracy.append(pull()['Accuracy'][0])
            Recall.append(pull()['Recall'][0])
            Prec.append(pull()['Prec.'][0])
            F1.append(pull()['F1'][0])
            Kappa.append(pull()['Kappa'][0])
            MCC.append(pull()['MCC'][0])
            AUC_df=pd.DataFrame(AUC)
            Accuracy_df=pd.DataFrame(Accuracy)
            Recall_df=pd.DataFrame(Recall)
            Prec_df=pd.DataFrame(Prec)
            F1_df=pd.DataFrame(F1)
            Kappa_df=pd.DataFrame(Kappa)
            MCC_df=pd.DataFrame(MCC)
            AUC_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_AUC_%d.csv" % (n,x))
            Accuracy_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Acc_%d.csv" % (n,x))
            Recall_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Recall_%d.csv" % (n,x))
            Prec_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Prec_%d.csv" % (n,x))
            F1_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_F1_%d.csv" % (n,x))
            Kappa_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_Kappa_%d.csv" % (n,x))
            MCC_df.to_csv("./ai_results_1000/AI_var_model_results_%d_genes_MCC_%d.csv" % (n,x))
